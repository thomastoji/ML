# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("rt.csv")
df
# Out:
#         day temperature windspeed  event
# 0  1/1/2017         32F      6mph   Rain
# 1  1/2/2017         NaN         7  Sunny
# 2  1/3/2017          28       NaN   Snow
# 3  1/4/2017         NaN      7mph  Sunny
# 4  1/5/2017          32       NaN   Rain
# 5  1/6/2017         31C         2  Sunny
# 6  1/6/2017          34         5  Sunny

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
fd = df.replace(-99999, np.NaN)

# %%
fd
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
df
# Out:
#   day\ttemperature\twindspeed\tevent
# 0             1/1/2017\t32F\t6\tRain
# 1         1/2/2017\t-99999\t7\tSunny
# 2         1/3/2017\t28\t-99999\tSnow
# 3      1/4/2017\t-99999\t7\tNo Event
# 4         1/5/2017\t32\t-99999\tRain
# 5             1/6/2017\t31\t2\tSunny
# 6          1/6/2017\t34\t5\tNo Event

# %%
fd = df.replace({-99999: "NaN",
                "No Event" : "Sunny"})
fd
# Out:
#         day temperature windspeed  event
# 0  1/1/2017          32         6   Rain
# 1  1/2/2017         NaN         7  Sunny
# 2  1/3/2017          28       NaN   Snow
# 3  1/4/2017         NaN         7  Sunny
# 4  1/5/2017          32       NaN   Rain
# 5  1/6/2017          31         2  Sunny
# 6  1/6/2017          34         5  Sunny

# %%
df
# Out:
#   day\ttemperature\twindspeed\tevent
# 0             1/1/2017\t32F\t6\tRain
# 1         1/2/2017\t-99999\t7\tSunny
# 2         1/3/2017\t28\t-99999\tSnow
# 3      1/4/2017\t-99999\t7\tNo Event
# 4         1/5/2017\t32\t-99999\tRain
# 5             1/6/2017\t31\t2\tSunny
# 6          1/6/2017\t34\t5\tNo Event
